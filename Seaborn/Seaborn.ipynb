# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.set_style("whitegrid")
data = np.random.normal(size=(20,10)) + np.arange(10) / 2
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.set_style("darkgrid")
data = np.random.normal(size=(20,10)) + np.arange(10) / 2
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
arr = np.array([1,2,3,4,5,1,1,1,1,2,2,2,2,19,10,10,10,19,4,4,5,5])

# %%
sns.countplot(arr,palette="ocean") #y axis is count by default
# Out:
# /home/spark/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(arr,x="Random Numbers For Count Plot",palette="ocean")
plt.title("Count Plot In Seaborn")
plt.ylabel("Count")
plt.xlabel("Numbers")
# Out:
# /home/spark/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'Numbers')

# %%
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
data = np.random.normal(size=(20,10)) + np.arange(10) / 2
sns.boxplot(data=data)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

data = pd.read_csv("biomech.csv")
data.sample(5)
# Out:
#      pelvic_incidence  pelvic_tilt numeric  lumbar_lordosis_angle  \
# 55          47.657730            13.277385              36.679985
# 84          76.326002            42.396204              57.200000
# 110         63.900633            13.706204              62.124334
# 229         43.436451            10.095743              36.032224
# 269         37.140150            16.481240              24.000000
#
#      sacral_slope  pelvic_radius  degree_spondylolisthesis     class
# 55      34.380345      98.249781                  6.273012  Abnormal
# 84      33.929797     124.267007                 50.127457  Abnormal
# 110     50.194429     114.129243                 41.422828  Abnormal
# 229     33.340707     137.439694                 -3.114451    Normal
# 269     20.658910     125.014361                  7.366425    Normal

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#We also use Heatmap to check the coorelation among the data

sns.heatmap(data.corr(),cmap="gist_gray")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr()) #default
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data,palette="bone")

# %%
sns.countplot(data=data,x="class",palette="Greens")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
x = np.array([10,20,30,40,50])
y = np.array([6,19,21,8,2])

sns.barplot(x,y)
# Out:
# /home/spark/.local/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
sns.histplot(data=data,x="pelvic_radius")
# Out:
# <AxesSubplot:xlabel='pelvic_radius', ylabel='Count'>
